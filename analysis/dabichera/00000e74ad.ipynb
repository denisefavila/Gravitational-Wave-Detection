# %%
import numpy as np

file = '00000e74ad.npy'

data = np.load(file)

# %%
from gwpy.timeseries import TimeSeries
from gwpy.time import to_gps

gps = to_gps('Apr 21 1991 02:30:45.391')

# %%
dect1 = TimeSeries(data[0], t0=gps, sample_rate=2**11, name='Strain')

spec1 = dect1.q_transform(frange=(30, 645), qrange=(30, 50))

plot = spec1.plot()
ax = plot.gca()
ax.set_epoch(gps)
ax.set_yscale('log')
ax.colorbar(label="Normalised energy")
plot.colorbars[0].mappable.set_clim(0,20)
# Out:
# <Plot size 864x432 with 2 Axes>

# %%
dect2 = TimeSeries(data[1], t0=gps, sample_rate=2**11, name='Strain')

spec2 = dect2.q_transform(frange=(30, 645), qrange=(30, 50))

plot = spec2.plot()
ax = plot.gca()
ax.set_epoch(gps)
ax.set_yscale('log')
ax.colorbar(label="Normalised energy")
plot.colorbars[0].mappable.set_clim(0,20)
# Out:
# <Plot size 864x432 with 2 Axes>

# %%
dect3 = TimeSeries(data[2], t0=gps, sample_rate=2**11, name='Strain')

spec3 = dect3.q_transform(frange=(30, 645), qrange=(30, 50))

plot = spec3.plot()
ax = plot.gca()
ax.set_epoch(gps)
ax.set_yscale('log')
ax.colorbar(label="Normalised energy")
plot.colorbars[0].mappable.set_clim(0,20)
# Out:
# <Plot size 864x432 with 2 Axes>
